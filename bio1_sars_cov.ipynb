# %% [markdown]
# # Bioinformatics Project 1.1 (Coronavirus)

# %%
import pandas as pd
import numpy as np
from openbabel import pybel
from IPython.display import SVG
from rdkit import Chem
from rdkit.Chem import Descriptors, Draw
from rdkit.Chem.Draw import IPythonConsole
from chembl_webresource_client.new_client import new_client
IPythonConsole.ipython_useSVG = True

# %%
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)

# %%
targets
# Out:
#    cross_references                                           organism  \
# 0                []                                        Coronavirus
# 1                []                                 Feline coronavirus
# 2                []                                 Murine coronavirus
# 3                []                                 Canine coronavirus
# 4                []                                 Bovine coronavirus
# 5                []                             Human coronavirus 229E
# 6                []                             Human coronavirus OC43
# 7                []                     unidentified human coronavirus
# 8                []                             Human coronavirus NL63
# 9                []  Middle East respiratory syndrome-related coron...
# 10               []  Severe acute respiratory syndrome-related coro...
# 11               []  Severe acute respiratory syndrome-related coro...
# ...

# %%
targets.columns
# Out:
# Index(['cross_references', 'organism', 'pref_name', 'score',
#        'species_group_flag', 'target_chembl_id', 'target_components',
#        'target_type', 'tax_id'],
#       dtype='str')

# %%
selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL613837'

# %% [markdown]
# Retrieve only bioactivity data for Human coronavirus (CHEMBL613732) that are reported as pChEMBL values.

# %%
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(results)
df.shape
# Out:
# (85, 47)

# %%
df.head()
# Out:
#   action_type activity_comment  activity_id  \
# 0        None             None     22804102
# 1        None             None     24984054
# 2        None             None     24992649
# 3        None             None     24992650
# 4        None             None     24992680
#
#                                  activity_properties assay_chembl_id  \
# 0  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4712028
# 1  [{'comments': None, 'relation': '<=', 'result_...   CHEMBL5227023
# 2                                                 []   CHEMBL5230448
# 3                                                 []   CHEMBL5230448
# 4  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5230463
#
#                                    assay_description assay_type  \
# 0  Antiviral activity against HCoV-229E infected ...          F
# 1  Antiviral activity against recombinant HCoV-22...          F
# 2               Antiviral activity against HCoV-229E          F
# ...
